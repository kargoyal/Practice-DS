# %%
import pandas as pd
import re
import seaborn as sb
import numpy as ny

# %%
DF=pd.read_csv(r"C:\Users\ShinChan\Downloads\top50 (1).csv",encoding="latin-1")

# %%
DF.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
DF.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
one=DF[DF["Popularity"]>80]

# %%
len(DF[DF["Popularity"]>90])
# Out:
# 13

# %%
DF.count()
# Out:
# Unnamed: 0          50
# Track.Name          50
# Artist.Name         50
# Genre               50
# Beats.Per.Minute    50
# Energy              50
# Danceability        50
# Loudness..dB..      50
# Liveness            50
# Valence.            50
# Length.             50
# Acousticness..      50
# Speechiness.        50
# Popularity          50
# dtype: int64

# %%
DF[DF["Beats.Per.Minute"]>DF["Beats.Per.Minute"].max()-1]
# Out:
#    Unnamed: 0                     Track.Name    Artist.Name      Genre  \
# 2           3  boyfriend (with Social House)  Ariana Grande  dance pop
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 2               190      80            40              -4        16        70
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 2      186              12            46          85

# %%
DF[DF["Beats.Per.Minute"]==DF["Beats.Per.Minute"].min()]
# Out:
#     Unnamed: 0             Track.Name       Artist.Name      Genre  \
# 30          31               Takeaway  The Chainsmokers        edm
# 41          42  You Need To Calm Down      Taylor Swift  dance pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 30                85      51            29              -8        10
# 41                85      68            77              -6         7
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 30        36      210              12             4          84
# 41        73      171               1             5          90

# %%
DF["track_name_length"]=DF["Track.Name"].apply(lambda l : len(l))

# %%
DF.groupby('Popularity')['Track.Name'].transform(lambda x: x.rank())
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     3.0
# 7     1.0
# 8     2.0
# 9     1.0
# 10    1.0
# 11    2.0
# 12    7.0
# 13    3.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    6.0
# 18    5.0
# 19    7.0
# 20    4.0
# 21    3.0
# 22    2.0
# 23    5.0
# 24    8.0
# 25    1.0
# 26    1.0
# 27    3.0
# 28    1.0
# 29    5.0
# 30    2.0
# 31    2.0
# 32    1.0
# 33    7.0
# 34    4.0
# 35    6.0
# 36    2.0
# 37    1.0
# 38    1.0
# 39    1.0
# 40    4.0
# 41    3.0
# 42    4.0
# 43    3.0
# 44    2.0
# 45    6.0
# 46    8.0
# 47    3.0
# 48    1.0
# 49    1.0
# Name: Track.Name, dtype: float64

# %%
DF[DF.Genre=='dance pop'].sum()
# Out:
# Unnamed: 0                                                        223
# Track.Name          boyfriend (with Social House)Loco Contigo (fea...
# Artist.Name         Ariana GrandeDJ SnakeChris BrownAriana GrandeK...
# Genre               dance popdance popdance popdance popdance popd...
# Beats.Per.Minute                                                  895
# Energy                                                            479
# Danceability                                                      562
# Loudness..dB..                                                    -49
# Liveness                                                          124
# Valence.                                                          367
# Length.                                                          1621
# Acousticness..                                                    216
# Speechiness.                                                      122
# ...

# %%
DF.tail(13)
# Out:
#     Unnamed: 0                                         Track.Name  \
# 37          38                     Antisocial (with Travis Scott)
# 38          39                                             Sucker
# 39          40  fuck, i'm lonely (with Anne-Marie) - from 13 ...
# 40          41                                        Higher Love
# 41          42                              You Need To Calm Down
# 42          43                                            Shallow
# 43          44                                               Talk
# 44          45                                         Con Altura
# 45          46                                    One Thing Right
# 46          47                                          Te Robaré
# 47          48                                            Happier
# 48          49                                      Call You Mine
# 49          50      Cross Me (feat. Chance the Rapper & PnB Rock)
#
# ...

# %%
DF["track_name_length"]=(DF["Track.Name"].apply(lambda l : len(l)))+(DF["Artist.Name"].apply(lambda l : len(l)))

# %%
DF["Artist_first_name"]=DF["Artist.Name"].apply(lambda l: (l.split(" "))[0])

# %%
DF
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
DF[DF["Genre"]=="dance pop"][["Genre"]].count()
# Out:
# Genre    8
# dtype: int64

# %%
p=[]
for i in DF["Genre"]:
    if i not in p:
        p.append(i)
        print(i,len(DF[DF["Genre"]==i]))
# Out:
# canadian pop 2
# reggaeton flow 2
# dance pop 8
# pop 7
# dfw rap 2
# trap music 1
# country rap 2
# electropop 2
# reggaeton 2
# panamanian pop 2
# canadian hip hop 3
# latin 5
# escape room 1
# pop house 1
# australian pop 1
# edm 3
# atl hip hop 1
# big room 1
# boy band 1
# r&b en espanol 1
# brostep 2

# %%
p=[]
for i in DF["Artist.Name"]:
    if i not in p:
        p.append(i)
        print(i,len(DF[DF["Artist.Name"]==i]))
# Out:
# Shawn Mendes 2
# Anuel AA 1
# Ariana Grande 2
# Ed Sheeran 4
# Post Malone 2
# Lil Tecca 1
# Sam Smith 1
# Lil Nas X 2
# Billie Eilish 2
# Bad Bunny 1
# DJ Snake 1
# Lewis Capaldi 1
# Sech 2
# Drake 1
# Chris Brown 1
# J Balvin 2
# Y2K 1
# Lizzo 1
# MEDUZA 1
# Jhay Cortez 1
# Lunay 1
# Tones and I 1
# Ali Gatie 1
# Daddy Yankee 1
# The Chainsmokers 2
# Maluma 1
# Young Thug 1
# Katy Perry 1
# Martin Garrix 1
# Jonas Brothers 1
# Lauv 1
# Kygo 1
# Taylor Swift 1
# Lady Gaga 1
# Khalid 1
# ROSALÍA 1
# Marshmello 2
# Nicky Jam 1

# %%
DF.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  track_name_length  \
# 0               4             3          79                 20
# 1               8             9          92                 13
#
#   Artist_first_name
# 0             Shawn
# 1             Anuel

# %%
len(DF.groupby(["Popularity"]).filter(lambda l : len(l["Popularity"])==1))
# Out:
# 8

# %%
len(DF["Popularity"])-len(DF.groupby(["Popularity"]).filter(lambda l : len(l["Popularity"])==1))
# Out:
# 42

# %%
DF["Rank"]=DF.groupby(["Popularity"]).filter(lambda l:len(l["Popularity"])==1)

# %%
sorted(DF.Popularity.unique())
# Out:
# [70, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95]

# %%
DF["Rank"]=DF[DF["Popularity"]>=70]["Rank"].apply(lambda l:1)

# %%
aa=list(DF["Popularity"])
aa
# Out:
# [79,
#  92,
#  85,
#  86,
#  94,
#  84,
#  92,
#  90,
#  87,
#  95,
#  93,
#  86,
#  88,
#  87,
#  92,
#  82,
#  90,
#  91,
#  88,
#  91,
#  91,
#  91,
#  83,
#  91,
#  89,
#  70,
#  83,
#  89,
#  91,
#  89,
#  84,
#  89,
#  89,
#  89,
#  89,
#  89,
#  91,
#  87,
#  80,
#  78,
#  88,
#  90,
#  87,
#  84,
#  88,
#  88,
#  88,
#  88,
#  88,
#  82]

# %%
sd=sorted(list(DF["Popularity"].unique()),reverse=True)

# %%
dd={}
for i in range(1,len(sd)+1):
    dd[i]=sd[i-1]

# %%
dd
# Out:
# {1: 95,
#  2: 94,
#  3: 93,
#  4: 92,
#  5: 91,
#  6: 90,
#  7: 89,
#  8: 88,
#  9: 87,
#  10: 86,
#  11: 85,
#  12: 84,
#  13: 83,
#  14: 82,
#  15: 80,
#  16: 79,
#  17: 78,
#  18: 70}

# %%
qq=[]
for k in range(len(aa)):
    for i,j in dd.items():
        if aa[k] == j:
            qq.append(i)

# %%
DF["rank"]=qq

# %%
DF.head(6)
# Out:
#    Unnamed: 0                         Track.Name    Artist.Name  \
# 0           1                           Señorita   Shawn Mendes
# 1           2                              China       Anuel AA
# 2           3      boyfriend (with Social House)  Ariana Grande
# 3           4    Beautiful People (feat. Khalid)     Ed Sheeran
# 4           5        Goodbyes (Feat. Young Thug)    Post Malone
# 5           6  I Don't Care (with Justin Bieber)     Ed Sheeran
#
#             Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0    canadian pop               117      55            76              -6
# 1  reggaeton flow               105      81            79              -4
# 2       dance pop               190      80            40              -4
# 3             pop                93      65            64              -8
# 4         dfw rap               150      65            58              -4
# ...

# %%
DF[["rank","Popularity"]].sort_values("rank")
# Out:
#     rank  Popularity
# 9      1          95
# 4      2          94
# 10     3          93
# 1      4          92
# 6      4          92
# 14     4          92
# 21     5          91
# 20     5          91
# 19     5          91
# 28     5          91
# 17     5          91
# 23     5          91
# 36     5          91
# 16     6          90
# 7      6          90
# 41     6          90
# 32     7          89
# 31     7          89
# 34     7          89
# 29     7          89
# 35     7          89
# 27     7          89
# 33     7          89
# 24     7          89
# 48     8          88
# 46     8          88
# 40     8          88
# 18     8          88
# 47     8          88
# 44     8          88
# 12     8          88
# 45     8          88
# 42     9          87
# 13     9          87
# 8      9          87
# 37     9          87
# 11    10          86
# 3     10          86
# 2     11          85
# 5     12          84
# 30    12          84
# 43    12          84
# ...

# %%
aw=DF["Danceability"]
gg=sorted(aw.unique(),reverse=True)
cd={}
hj=[]
for i in range(1,len(gg)+1):
    cd[i]=gg[i-1]
for i in range(len(aw)):
    for j,k in cd.items():
        if aw[i]==k:
            hj.append(j)
DF["Rank"]=hj
DF[["Rank","Danceability"]].sort_values("Rank")
# Out:
#     Rank  Danceability
# 43     1            90
# 44     2            88
# 8      2            88
# 18     3            84
# 38     3            84
# 14     4            83
# 26     5            82
# 11     5            82
# 22     6            81
# 39     6            81
# 5      7            80
# 23     7            80
# 33     7            80
# 1      8            79
# 32     9            78
# 31     9            78
# 34    10            77
# 41    10            77
# 17    11            76
# 0     11            76
# 36    12            75
# 49    12            75
# 16    12            75
# 6     12            75
# 28    13            74
# 27    14            73
# 13    14            73
# 19    15            72
# 37    15            72
# 15    16            70
# 21    16            70
# 9     16            70
# 47    17            69
# 25    17            69
# 40    17            69
# 20    18            68
# 46    19            67
# 24    19            67
# 45    20            66
# ...

# %%
DF["Danceability"].sum(axis=0)
# Out:
# 3569

# %%
gy=DF.info()
DF.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 17 columns):
# Unnamed: 0          50 non-null int64
# Track.Name          50 non-null object
# Artist.Name         50 non-null object
# for                 50 non-null object
# Beats.Per.Minute    50 non-null int64
# def                 50 non-null int64
# Danceability        50 non-null int64
# Loudness..dB..      50 non-null int64
# Liveness            50 non-null int64
# Valence.            50 non-null int64
# Length.             50 non-null int64
# Acousticness..      50 non-null int64
# Speechiness.        50 non-null int64
# Popularity          50 non-null int64
# rank                50 non-null int64
# Rank                50 non-null int64
# new                 0 non-null float64
# dtypes: float64(1), int64(13), object(3)
# memory usage: 9.5+ KB
#        Unnamed: 0  Beats.Per.Minute        def  Danceability  Loudness..dB..  \
# ...

# %%
DF.loc[51]=DF.loc[48]
DF[DF.duplicated()]
# Out:
#     Unnamed: 0     Track.Name       Artist.Name  for  Beats.Per.Minute  def  \
# 51          49  Call You Mine  The Chainsmokers  edm               104   70
#
#     Danceability  Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# 51            59              -6        41        50      218              23
#
#     Speechiness.  Popularity  rank  Rank  new
# 51             3          88     8    23  NaN

# %%
DF.tail(4)
# Out:
#     Unnamed: 0                                     Track.Name  \
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
# 51          49                                  Call You Mine
#
#          Artist.Name      for  Beats.Per.Minute  def  Danceability  \
# 47        Marshmello  brostep               100   79            69
# 48  The Chainsmokers      edm               104   70            59
# 49        Ed Sheeran      pop                95   79            75
# 51  The Chainsmokers      edm               104   70            59
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 47              -3        17        67      214              19             5
# 48              -6        41        50      218              23             3
# 49              -6         7        61      206              21            12
# ...

# %%
DF["Track.Name"].mode()
# Out:
# 0    Call You Mine
# dtype: object

# %%
DF.drop(index=51,inplace=True)

# %%
DF[DF["Danceability"]==69]
# Out:
#     Unnamed: 0           Track.Name   Artist.Name           for  \
# 25          26  If I Can't Have You  Shawn Mendes  canadian pop
# 40          41          Higher Love          Kygo           edm
# 47          48              Happier    Marshmello       brostep
#
#     Beats.Per.Minute  def  Danceability  Loudness..dB..  Liveness  Valence.  \
# 25               124   82            69              -4        13        87
# 40               104   68            69              -7        10        40
# 47               100   79            69              -3        17        67
#
#     Length.  Acousticness..  Speechiness.  Popularity  rank  Rank  new
# 25      191              49             6          70    18    17  NaN
# 40      228               2             3          88     8    17  NaN
# 47      214              19             5          88     8    17  NaN

# %%
DS=DF.select_dtypes(include="int64")
DS.head(3)
# Out:
#    Unnamed: 0  Beats.Per.Minute  def  Danceability  Loudness..dB..  Liveness  \
# 0           1               117   55            76              -6         8
# 1           2               105   81            79              -4         8
# 2           3               190   80            40              -4        16
#
#    Valence.  Length.  Acousticness..  Speechiness.  Popularity  rank  Rank
# 0        75      191               4             3          79    16    11
# 1        61      302               8             9          92     4     8
# 2        70      186              12            46          85    11    28

# %%
for i in DS.columns:
    print("mean                    ",DS[[i]].mean(axis=0))
    print("min                    ",DS[[i]].min(axis=0))
    print("max                    ",DS[[i]].max(axis=0))
    print("std                    ",DS[[i]].std(axis=0))
# Out:
# mean                     Unnamed: 0    25.5
# dtype: float64
# min                     Unnamed: 0    1
# dtype: int64
# max                     Unnamed: 0    50
# dtype: int64
# std                     Unnamed: 0    14.57738
# dtype: float64
# mean                     Beats.Per.Minute    120.06
# dtype: float64
# min                     Beats.Per.Minute    85
# dtype: int64
# max                     Beats.Per.Minute    190
# dtype: int64
# std                     Beats.Per.Minute    30.898392
# dtype: float64
# mean                     Energy    64.06
# dtype: float64
# min                     Energy    32
# dtype: int64
# max                     Energy    88
# dtype: int64
# std                     Energy    14.231913
# dtype: float64
# mean                     Danceability    71.38
# dtype: float64
# min                     Danceability    29
# dtype: int64
# max                     Danceability    90
# dtype: int64
# std                     Danceability    11.92988
# ...

# %%
for i in DS.index:
    print("max                   " ,DS.loc[i].max())
    print("min                   " ,DS.loc[i].min())
    print("mean                   " ,DS.loc[i].mean())
    print("std                   " ,DS.loc[i].std())
# Out:
# max                    191
# min                    -6
# mean                    48.46153846153846
# std                    58.31611467484121
# max                    302
# min                    -4
# mean                    58.07692307692308
# std                    83.50495148838134
# max                    190
# min                    -4
# mean                    58.69230769230769
# std                    64.21628118499831
# max                    198
# min                    -8
# mean                    48.23076923076923
# std                    55.93471469215078
# max                    175
# min                    -4
# mean                    50.0
# std                    57.87198516265592
# max                    220
# min                    -5
# mean                    52.30769230769231
# std                    63.77223091516742
# max                    180
# min                    -6
# mean                    47.69230769230769
# std                    57.622889860691956
# ...

# %%
DS.mean()
# Out:
# Unnamed: 0           25.50
# Beats.Per.Minute    120.06
# Energy               64.06
# Danceability         71.38
# Loudness..dB..       -5.66
# Liveness             14.66
# Valence.             54.60
# Length.             200.96
# Acousticness..       22.16
# Speechiness.         12.48
# Popularity           87.50
# rank                  8.28
# Rank                 13.14
# dtype: float64

# %%
DS.mean(axis=1)
# Out:
# 0     48.461538
# 1     58.076923
# 2     58.692308
# 3     48.230769
# 4     50.000000
# 5     52.307692
# 6     47.692308
# 7     47.846154
# 8     48.769231
# 9     53.076923
# 10    62.538462
# 11    48.538462
# 12    49.692308
# 13    65.153846
# 14    45.153846
# 15    49.769231
# 16    59.923077
# 17    50.000000
# 18    47.230769
# 19    51.384615
# 20    48.000000
# 21    48.307692
# 22    59.230769
# 23    61.769231
# 24    54.307692
# 25    57.538462
# 26    55.538462
# 27    50.615385
# 28    51.615385
# 29    58.384615
# 30    42.769231
# 31    53.000000
# 32    52.384615
# 33    47.307692
# 34    55.461538
# 35    48.538462
# 36    62.153846
# 37    58.230769
# 38    55.692308
# 39    53.461538
# 40    51.615385
# 41    48.384615
# 42    50.846154
# 43    50.384615
# 44    52.846154
# 45    51.692308
# 46    61.230769
# 47    56.000000
# 48    56.153846
# 49    54.461538
# dtype: float64

# %%
meana=list(DS.mean(axis=1))

# %%
DF.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'for', 'Beats.Per.Minute',
#        'def', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity', 'rank',
#        'Rank', 'new'],
#       dtype='object')

# %%
DF.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  rank  Rank
# 0               4             3          79    16    11
# 1               8             9          92     4     8

# %%
DF.rename(columns={"Genre":"for"},inplace=True)

# %%
DF
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
DF[DF["for"]=="edm"]
# Out:
#     Unnamed: 0     Track.Name       Artist.Name  for  Beats.Per.Minute  def  \
# 30          31       Takeaway  The Chainsmokers  edm                85   51
# 40          41    Higher Love              Kygo  edm               104   68
# 48          49  Call You Mine  The Chainsmokers  edm               104   70
#
#     Danceability  Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# 30            29              -8        10        36      210              12
# 40            69              -7        10        40      228               2
# 48            59              -6        41        50      218              23
#
#     Speechiness.  Popularity  rank  Rank  new
# 30             4          84    12    29  NaN
# 40             3          88     8    17  NaN
# 48             3          88     8    23  NaN

# %%
(DF[DF["for"]=="edm"])["Length."].mean()
# Out:
# 218.66666666666666

# %%
list((DF[DF["for"]=="edm"])["Length."].apply(lambda j : j-(DF[DF["for"]=="edm"])["Length."].mean()))
# Out:
# [-8.666666666666657, 9.333333333333343, -0.6666666666666572]

# %%
DF["length_variance"]=list(range(len(DF["for"])))

for j in range(len(DF['for'])):
        DF["length_variance"][j] = DF["Length."][j]-DF[DF["for"]==DF["for"][j]]["Length."].mean()
        
DF[DF["Length."]==191]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     Unnamed: 0           Track.Name   Artist.Name           for  \
# 0            1             Señorita  Shawn Mendes  canadian pop
# 25          26  If I Can't Have You  Shawn Mendes  canadian pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 0                117      55            76              -6         8
# 25               124      82            69              -4        13
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity  \
# 0         75      191               4             3          79
# 25        87      191              49             6          70
#
#     length_variance
# ...

# %%
DF.groupby("for")["Length."].mean()
# Out:
# for
# atl hip hop         200.000000
# australian pop      210.000000
# big room            164.000000
# boy band            181.000000
# brostep             198.000000
# canadian hip hop    193.000000
# canadian pop        191.000000
# country rap         136.000000
# dance pop           202.625000
# dfw rap             166.500000
# edm                 218.666667
# electropop          194.500000
# escape room         173.000000
# latin               225.200000
# panamanian pop      257.000000
# pop                 195.428571
# pop house           153.000000
# r&b en espanol      162.000000
# reggaeton           213.500000
# reggaeton flow      305.500000
# trap music          131.000000
# Name: Length., dtype: float64

# %%
 DF["Length."][0]
# Out:
# 191

# %%
DF["for"].nunique()
# Out:
# 21

# %%
(DF[DF["for"]=="dance pop"])[["Length."]].mean()
# Out:
# Length.    202.625
# dtype: float64

# %%
DF[DF["for"]=="dance pop"]
# Out:
#     Unnamed: 0                                         Track.Name  \
# 2            3                      boyfriend (with Social House)
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 15          16                          No Guidance (feat. Drake)
# 31          32                                            7 rings
# 34          35                                  Never Really Over
# 39          40  fuck, i'm lonely (with Anne-Marie) - from 13 ...
# 41          42                              You Need To Calm Down
# 42          43                                            Shallow
#
#       Artist.Name        for  Beats.Per.Minute  Energy  Danceability  \
# 2   Ariana Grande  dance pop               190      80            40
# 11       DJ Snake  dance pop                96      71            82
# 15    Chris Brown  dance pop                93      45            70
# 31  Ariana Grande  dance pop               140      32            78
# ...

# %%
DF["log_loudness_db"]=list(range(len(DF["for"])))
for i in range(len(DF["for"])):
    if DF["Loudness..dB.."][i] <0:
        DF["log_loudness_db"][i]=float(ny.log(-(DF["Loudness..dB.."][i])))
    elif DF["Loudness..dB.."][i] >0:
        DF["log_loudness_db"][i]=float(ny.log(DF["Loudness..dB.."][i]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ny.log(-(DF["Loudness..dB.."][9]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# nan

# %%
DF["Loudness..dB.."][2]=ny.log(-(DF["Loudness..dB.."][2]))
DF["Loudness..dB.."][2]
float(ny.log(6))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1.791759469228055

# %%
DF
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
DF.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
# Unnamed: 0          50 non-null int64
# Track.Name          50 non-null object
# Artist.Name         50 non-null object
# Genre               50 non-null object
# Beats.Per.Minute    50 non-null int64
# Energy              50 non-null int64
# Danceability        50 non-null int64
# Loudness..dB..      50 non-null int64
# Liveness            50 non-null int64
# Valence.            50 non-null int64
# Length.             50 non-null int64
# Acousticness..      50 non-null int64
# Speechiness.        50 non-null int64
# Popularity          50 non-null int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
DF.Genre.value_counts()
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton flow      2
# country rap         2
# brostep             2
# canadian pop        2
# electropop          2
# dfw rap             2
# panamanian pop      2
# reggaeton           2
# big room            1
# escape room         1
# australian pop      1
# boy band            1
# atl hip hop         1
# r&b en espanol      1
# pop house           1
# trap music          1
# Name: Genre, dtype: int64

# %%
DF.Genre.unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
DF["lol"]=DF["Genre"]

# %%
DF.tail()
# Out:
#     Unnamed: 0                                     Track.Name  \
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
# 51          49                                  Call You Mine
# 52          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name    Genre  Beats.Per.Minute  Energy  Danceability  \
# 47        Marshmello  brostep               100      79            69
# 48  The Chainsmokers      edm               104      70            59
# 49        Ed Sheeran      pop                95      79            75
# 51  The Chainsmokers      edm               104      70            59
# 52        Ed Sheeran      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 47              -3        17        67      214              19             5
# ...

# %%
DF.loc[51]=DF.loc[48]

# %%
DF.loc[52]=DF.loc[49]

# %%
DF[DF.duplicated()]
# Out:
#     Unnamed: 0                                     Track.Name  \
# 51          49                                  Call You Mine
# 52          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name Genre  Beats.Per.Minute  Energy  Danceability  \
# 51  The Chainsmokers   edm               104      70            59
# 52        Ed Sheeran   pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 51              -6        41        50      218              23             3
# 52              -6         7        61      206              21            12
#
#     Popularity
# 51          88
# 52          82

# %%
for i in range(1,int(input())):
    print(str(i)*i)
# Out:
# 5
# 1
# 22
# 333
# 4444

# %%
str
