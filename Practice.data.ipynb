# %%
import numpy as ny
import pandas as ps
import matplotlib as ml
import seaborn as se

# %%
DF=ps.read_csv(r"C:\Users\ShinChan\Downloads\practice.csv")

# %%
DF.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LotConfig',
#        'LandSlope', 'OverallQual', 'YearBuilt', 'MasVnrArea', 'ExterQual',
#        'BsmtExposure'],
#       dtype='object')

# %%
DF.select_dtypes(include="object")
# Out:
#    MSZoning LotShape LotConfig LandSlope ExterQual BsmtExposure
# 0        RL      Reg    Inside       Gtl        Gd           No
# 1        RL      Reg       FR2       Gtl        TA           Gd
# 2        RL      IR1    Inside       Gtl        Gd           Mn
# 3        RL      IR1    Corner       Gtl        TA           No
# 4        RL      IR1       FR2       Gtl        Gd           Av
# 5        RL      IR1    Inside       Gtl        TA           No
# 6        RL      Reg    Inside       Gtl        Gd           Av
# 7        RL      IR1    Corner       Gtl        TA           Mn
# 8        RM      Reg    Inside       Gtl        TA           No
# 9        RL      Reg    Corner       Gtl        TA           No
# 10       RL      Reg    Inside       Gtl        TA           No
# 11       RL      IR1    Inside       Gtl        Ex           No
# 12       RL      IR2    Inside       Gtl        TA           No
# 13       RL      IR1    Inside       Gtl        Gd           Av
# ...

# %%
DF.select_dtypes(exclude="object")
# Out:
#     MSSubClass  LotArea  OverallQual  YearBuilt  MasVnrArea
# 0           60     8450            7       2003         196
# 1           20     9600            6       1976           0
# 2           60    11250            7       2001         162
# 3           70     9550            7       1915           0
# 4           60    14260            8       2000         350
# 5           50    14115            5       1993           0
# 6           20    10084            8       2004         186
# 7           60    10382            7       1973         240
# 8           50     6120            7       1931           0
# 9          190     7420            5       1939           0
# 10          20    11200            5       1965           0
# 11          60    11924            9       2005         286
# 12          20    12968            5       1962           0
# 13          20    10652            7       2006         306
# 14          20    10920            6       1960         212
# ...

# %%
DF.shape
# Out:
# (30, 11)

# %%
DF.rename({"MSSubClass":"SubClass","MSZoning ":"Zones"})
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# ...

# %%
DF.MSZoning.value_counts()
# Out:
# RL    25
# RM     5
# Name: MSZoning, dtype: int64

# %%
DF.LotShape.value_counts()
# Out:
# Reg    16
# IR1    13
# IR2     1
# Name: LotShape, dtype: int64

# %%
DF.LotConfig.value_counts()
# Out:
# Inside     18
# Corner      8
# CulDSac     2
# FR2         2
# Name: LotConfig, dtype: int64

# %%
DF.YearBuilt.max()
# Out:
# 2007

# %%
DF.YearBuilt.min()
# Out:
# 1915

# %%
DF["Year_diff"]=DF.YearBuilt.apply(lambda l:2020-l)

# %%
DF.tail(3)
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 27          20       RL    11478      Reg    Inside       Gtl            8
# 28          20       RL    16321      IR1   CulDSac       Gtl            5
# 29          30       RM     6324      IR1    Inside       Gtl            4
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure  Year_diff
# 27       2007         200        Gd           No         13
# 28       1957           0        TA           Gd         63
# 29       1927           0        TA           No         93

# %%
DF.groupby(["MSZoning"])["OverallQual"].value_counts()
# Out:
# MSZoning  OverallQual
# RL        5              9
#           8              6
#           7              5
#           6              3
#           4              1
#           9              1
# RM        7              3
#           4              1
#           5              1
# Name: OverallQual, dtype: int64

# %%
DF.groupby(["MSZoning","OverallQual"]).get_group(("RM",7))
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 15          45       RM     6120      Reg    Corner       Gtl            7
# 21          45       RM     7449      Reg    Inside       Gtl            7
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure  Year_diff
# 8        1931           0        TA           No         89
# 15       1929           0        TA           No         91
# 21       1930           0        TA           No         90

# %%
DF[DF["BsmtExposure"]=="Mn"]["LotArea"].max()
# Out:
# 11250

# %%
DF.sort_values(by=["MSSubClass","YearBuilt"],ascending=[False,True])
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 23         120       RM     4224      Reg    Inside       Gtl            5
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 20          60       RL    14215      IR1    Corner       Gtl            8
# 8           50       RM     6120      Reg    Inside       Gtl            7
# ...

# %%
DF["OverallQual"].mean()
# Out:
# 6.3

# %%
DF["OverallQual"].mode()
# Out:
# 0    5
# dtype: int64

# %%
DF["OverallQual"].median()
# Out:
# 6.5

# %%
DF.groupby(["YearBuilt"])["OverallQual"].max()
# Out:
# YearBuilt
# 1915    7
# 1927    4
# 1929    7
# 1930    7
# 1931    7
# 1939    5
# 1951    5
# 1957    5
# 1958    5
# 1960    6
# 1962    5
# 1965    5
# 1967    4
# 1968    5
# 1970    6
# 1973    7
# 1976    6
# 1993    5
# 2000    8
# 2001    7
# 2002    8
# 2003    7
# 2004    8
# 2005    9
# 2006    7
# 2007    8
# Name: OverallQual, dtype: int64

# %%
DF.to_csv(r"C:\Users\ShinChan\Downloads\data_1.csv")

# %%
ps.read_csv(r"C:\Users\ShinChan\Downloads\data_1.csv")
# Out:
#     Unnamed: 0  MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  \
# 0            0          60       RL     8450      Reg    Inside       Gtl
# 1            1          20       RL     9600      Reg       FR2       Gtl
# 2            2          60       RL    11250      IR1    Inside       Gtl
# 3            3          70       RL     9550      IR1    Corner       Gtl
# 4            4          60       RL    14260      IR1       FR2       Gtl
# 5            5          50       RL    14115      IR1    Inside       Gtl
# 6            6          20       RL    10084      Reg    Inside       Gtl
# 7            7          60       RL    10382      IR1    Corner       Gtl
# 8            8          50       RM     6120      Reg    Inside       Gtl
# 9            9         190       RL     7420      Reg    Corner       Gtl
# 10          10          20       RL    11200      Reg    Inside       Gtl
# 11          11          60       RL    11924      IR1    Inside       Gtl
# ...

# %%
nu=DF.LotArea

# %%
DF["nu"]=nu

# %%
DF.MasVnrArea.replace({0:-1},inplace=True)

# %%
DF[DF["MasVnrArea"]==0]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotArea, LotShape, LotConfig, LandSlope, OverallQual, YearBuilt, MasVnrArea, ExterQual, BsmtExposure, Year_diff, nu]
# Index: []

# %%
DF["MSZoning"][0]="NaN"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
DF.isnull().count()
# Out:
# MSSubClass      30
# MSZoning        30
# LotArea         30
# LotShape        30
# LotConfig       30
# LandSlope       30
# OverallQual     30
# YearBuilt       30
# MasVnrArea      30
# ExterQual       30
# BsmtExposure    30
# dtype: int64

# %%
DF["MSZoning"][0]
# Out:
# 'NaN'

# %%
df=se.load_dataset("titanic")

# %%
se.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
o=df.isnull()

# %%
o.replace({True:1,False:0},inplace=True)

# %%
o.deck.sum()
# Out:
# 688

# %%
len(df.deck)
# Out:
# 891

# %%
(o.sum()/len(df))*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
DF.drop(columns="ExterQual")
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60      NaN     8450      Reg    Inside       Gtl            7
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# ...

# %%
DF[DF["LotConfig"]=="Inside"]
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60      NaN     8450      Reg    Inside       Gtl            7
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 12          20       RL    12968      IR2    Inside       Gtl            5
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 18          20       RL    13695      Reg    Inside       Gtl            5
# ...

# %%
DF.groupby(["LotShape"])["LotArea"].mean()
# Out:
# LotShape
# IR1    11492.307692
# IR2    12968.000000
# Reg     9085.187500
# Name: LotArea, dtype: float64
